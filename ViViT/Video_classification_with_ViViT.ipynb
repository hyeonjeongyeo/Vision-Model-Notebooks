# %% [markdown]
# ## Video classification with ViViT
#
# This notebook is written to test ViViT model with medical 3D dataset and codes of model are referenced from https://keras.io/examples/vision/vivit/. The key feature of the model is that it uses self-attention on temporal and spatial embeddings extracted from the input video, instead of extracting only spatial information with Convolution and applying attention methods.
#
# The test accuracy was 73.1% with SynapseMNIST3D(2-class) which was lower than 80.0% tested with OrganMNIST3D dataset(11-class), but no hyperparameters were adjusted. On further study, factorising and regularising methods can be tested with several types of datasets.
#
# ### Info
# - Model: [ViViT](https://arxiv.org/abs/2103.15691)
# - Dataset: [MVTecAD](https://www.mvtec.com/company/research/datasets/mvtec-ad/), SynapseMNIST3D
#
# ### Reference
# 1. https://keras.io/examples/vision/vivit/
# 2. https://arxiv.org/abs/2103.15691

# %%
# !pip install -qq medmnist

# %%
import os
import io
import imageio
import medmnist
import ipywidgets
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Setting seed for reproducibility
SEED = 23
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
keras.utils.set_random_seed(SEED)

# %%
# DATA
DATASET_NAME = "synapsemnist3d"
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = (28, 28, 28, 1)
NUM_CLASSES = 11

# OPTIMIZER
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 60

# TUBELET EMBEDDING
PATCH_SIZE = (8, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 8
NUM_LAYERS = 8

# %% [markdown]
# ## Dataset

# %%
def download_and_prepare_dataset(data_info: dict):
    """Utility function to download the dataset.

    Arguments:
        data_info (dict): Dataset metadata.
    """
    data_path = keras.utils.get_file(origin=data_info["url"], md5_hash=data_info["MD5"])

    with np.load(data_path) as data:
        # Get videos
        train_videos = data["train_images"]
        valid_videos = data["val_images"]
        test_videos = data["test_images"]

        # Get labels
        train_labels = data["train_labels"].flatten()
        valid_labels = data["val_labels"].flatten()
        test_labels = data["test_labels"].flatten()

    return (
        (train_videos, train_labels),
        (valid_videos, valid_labels),
        (test_videos, test_labels),
    )


# Get the metadata of the dataset
info = medmnist.INFO[DATASET_NAME]

# Get the dataset
prepared_dataset = download_and_prepare_dataset(info)
(train_videos, train_labels) = prepared_dataset[0]
(valid_videos, valid_labels) = prepared_dataset[1]
(test_videos, test_labels) = prepared_dataset[2]

# %% [markdown]
# ### tf.data pipeline

# %%
@tf.function
def preprocess(frames: tf.Tensor, label: tf.Tensor):
    """Preprocess the frames tensors and parse the labels."""
    # Preprocess images
    frames = tf.image.convert_image_dtype(
        frames[
            ..., tf.newaxis
        ],  # The new axis is to help for further processing with Conv3D layers
        tf.float32,
    )
    # Parse label
    label = tf.cast(label, tf.float32)
    return frames, label


def prepare_dataloader(
        videos: np.ndarray,
        labels: np.ndarray,
        loader_type: str = "train",
        batch_size: int = BATCH_SIZE,
    ):
    """Utility function to prepare the dataloader."""
    dataset = tf.data.Dataset.from_tensor_slices((videos, labels))

    if loader_type == "train":
        dataset = dataset.shuffle(BATCH_SIZE * 2)

    dataloader = (
        dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )
    return dataloader


trainloader = prepare_dataloader(train_videos, train_labels, "train")
validloader = prepare_dataloader(valid_videos, valid_labels, "valid")
testloader = prepare_dataloader(test_videos, test_labels, "test")

# %%
# number of samples
NUM_SAMPLES_VIZ = 25

trainsamples, labels = next(iter(trainloader))
trainsamples, labels = trainsamples[:NUM_SAMPLES_VIZ], labels[:NUM_SAMPLES_VIZ]

ground_truths = []
videos = []

for i, (trainsample, label) in enumerate(zip(trainsamples, labels)):
    # Generate gif
    with io.BytesIO() as gif:
        imageio.mimsave(gif, (trainsample.numpy() * 255).astype("uint8"), "GIF", fps=5)
        videos.append(gif.getvalue())

    ground_truths.append(label.numpy().astype("int"))


def make_box_for_grid(image_widget, fit):
    """Make a VBox to hold caption/image for demonstrating option_fit values.

    Source: https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Styling.html
    """
    # Make the caption
    if fit is not None:
        fit_str = "'{}'".format(fit)
    else:
        fit_str = str(fit)

    h = ipywidgets.HTML(value="" + str(fit_str) + "")

    # Make the green box with the image widget inside it
    boxb = ipywidgets.widgets.Box()
    boxb.children = [image_widget]

    # Compose into a vertical box
    vb = ipywidgets.widgets.VBox()
    vb.layout.align_items = "center"
    vb.children = [h, boxb]
    return vb


def show_samples(ground_truths, preds, videos):
    boxes = []
    for i in range(NUM_SAMPLES_VIZ):
        ib = ipywidgets.widgets.Image(value=videos[i], width=100, height=100)
        true_class = info["label"][str(ground_truths[i])]
        if preds:
            pred_class = info["label"][str(preds[i])]
            caption = f"T: {true_class} | P: {pred_class}"
        else:
            caption = f"T: {true_class}"
        boxes.append(make_box_for_grid(ib, caption))

    return ipywidgets.widgets.GridBox(
              boxes, layout=ipywidgets.widgets.Layout(grid_template_columns="repeat(5, 200px)")
            )

show_samples(ground_truths, [], videos)
# Out:
# GridBox(children=(VBox(children=(HTML(value="'T: excitatory synapse'"), Box(children=(Image(value=b'GIF89a\x1c…

# %% [markdown]
# <p align="center">
#   <img width="1000" height="600" src="/ViViT/img/synapse_train_sample.gif">
# </p>

# %% [markdown]
# ## Tubelet Embedding
#
# <p align="center">
#   <img width="460" height="300" src="https://i.imgur.com/aaPyLPX.png">
# </p>
# Uniform frame sampling
#
#
# <p align="center">
#   <img width="460" height="300" src="https://i.imgur.com/9G7QTfV.png">
# </p>
# Tubelet Embedding
#
# source : https://arxiv.org/abs/2103.15691
#
#
# Unlike Unifrom frame sampling, Tubelet Embedding captures temporal relation from the video.

# %%
class TubeletEmbedding(layers.Layer):
    def __init__(self, embed_dim, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.projection = layers.Conv3D(
            filters=embed_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="VALID",
        )
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))

    def call(self, videos):
        projected_patches = self.projection(videos)
        flattened_patches = self.flatten(projected_patches)
        return flattened_patches

# %% [markdown]
# ## Positional Embedding

# %%
class PositionalEncoder(layers.Layer):
    def __init__(self, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim

    def build(self, input_shape):
        _, num_tokens, _ = input_shape
        self.position_embedding = layers.Embedding(
            input_dim=num_tokens, output_dim=self.embed_dim
        )
        self.positions = tf.range(start=0, limit=num_tokens, delta=1)

    def call(self, encoded_tokens):
        # Encode the positions and add it to the encoded tokens
        encoded_positions = self.position_embedding(self.positions)
        encoded_tokens = encoded_tokens + encoded_positions
        return encoded_tokens

# %% [markdown]
# ## Video Vision Transformer
# Among the 4 variants suggested by the authors of Vision Transformer:
# - Spatio-temporal attention
# - Factorized encoder
# - Factorized self-attention
# - Factorized dot-product attention
#
# we implement the Spatio-temporal attention model for simplicity.

# %%
def create_vivit_classifier(
    tubelet_embedder,
    positional_encoder,
    input_shape=INPUT_SHAPE,
    transformer_layers=NUM_LAYERS,
    num_heads=NUM_HEADS,
    embed_dim=PROJECTION_DIM,
    layer_norm_eps=LAYER_NORM_EPS,
    num_classes=NUM_CLASSES,
):
    # Get the input layer
    inputs = layers.Input(shape=input_shape)
    # Create patches.
    patches = tubelet_embedder(inputs)
    # Encode patches.
    encoded_patches = positional_encoder(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization and MHSA
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim // num_heads, dropout=0.1
        )(x1, x1)

        # Skip connection
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer Normalization and MLP
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = keras.Sequential(
            [
                layers.Dense(units=embed_dim * 4, activation=tf.nn.gelu),
                layers.Dense(units=embed_dim, activation=tf.nn.gelu),
            ]
        )(x3)

        # Skip connection
        encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
    representation = layers.LayerNormalization(epsilon=layer_norm_eps)(encoded_patches)
    representation = layers.GlobalAvgPool1D()(representation)

    # Classify outputs.
    outputs = layers.Dense(units=num_classes, activation="softmax")(representation)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Train

# %%
def run_experiment():
    # Initialize model
    model = create_vivit_classifier(
        tubelet_embedder=TubeletEmbedding(
            embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
        ),
        positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
    )

    # Compile the model with the optimizer, loss function
    # and the metrics.
    optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    # Train the model.
    _ = model.fit(trainloader, epochs=EPOCHS, validation_data=validloader)

    _, accuracy, top_5_accuracy = model.evaluate(testloader)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return model


model = run_experiment()
# Out:
# Epoch 1/60
# 39/39 [==============================] - 38s 470ms/step - loss: 0.5509 - accuracy: 0.9130 - top-5-accuracy: 0.9780 - val_loss: 7.8396 - val_accuracy: 0.2712 - val_top-5-accuracy: 0.2712
# Epoch 2/60
# 39/39 [==============================] - 16s 419ms/step - loss: 2.8069 - accuracy: 0.5862 - top-5-accuracy: 0.7667 - val_loss: 1.6005 - val_accuracy: 0.2712 - val_top-5-accuracy: 1.0000
# Epoch 3/60
# 39/39 [==============================] - 16s 421ms/step - loss: 1.6928 - accuracy: 0.4187 - top-5-accuracy: 1.0000 - val_loss: 0.6231 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 4/60
# 39/39 [==============================] - 18s 452ms/step - loss: 0.8719 - accuracy: 0.6528 - top-5-accuracy: 1.0000 - val_loss: 0.6243 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 5/60
# 39/39 [==============================] - 16s 416ms/step - loss: 0.9196 - accuracy: 0.5748 - top-5-accuracy: 1.0000 - val_loss: 0.6078 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 6/60
# 39/39 [==============================] - 18s 452ms/step - loss: 0.8804 - accuracy: 0.6268 - top-5-accuracy: 1.0000 - val_loss: 0.6062 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 7/60
# 39/39 [==============================] - 16s 419ms/step - loss: 0.8631 - accuracy: 0.6789 - top-5-accuracy: 1.0000 - val_loss: 0.6030 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 8/60
# 39/39 [==============================] - 16s 420ms/step - loss: 0.8426 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.6016 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 9/60
# 39/39 [==============================] - 16s 423ms/step - loss: 0.8267 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5995 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 10/60
# 39/39 [==============================] - 17s 427ms/step - loss: 0.8117 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5984 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 11/60
# 39/39 [==============================] - 16s 420ms/step - loss: 0.7994 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5967 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 12/60
# 39/39 [==============================] - 18s 451ms/step - loss: 0.7903 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5958 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 13/60
# 39/39 [==============================] - 16s 417ms/step - loss: 0.7803 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5949 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 14/60
# 39/39 [==============================] - 16s 416ms/step - loss: 0.7713 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5941 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 15/60
# 39/39 [==============================] - 16s 418ms/step - loss: 0.7608 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5938 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 16/60
# 39/39 [==============================] - 16s 420ms/step - loss: 0.7547 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5931 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 17/60
# 39/39 [==============================] - 17s 431ms/step - loss: 0.7473 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5927 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 18/60
# 39/39 [==============================] - 19s 477ms/step - loss: 0.7455 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5919 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 19/60
# 39/39 [==============================] - 17s 425ms/step - loss: 0.7351 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5919 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 20/60
# 39/39 [==============================] - 16s 417ms/step - loss: 0.7299 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5912 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 21/60
# 39/39 [==============================] - 17s 430ms/step - loss: 0.7235 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5911 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 22/60
# 39/39 [==============================] - 16s 421ms/step - loss: 0.7219 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5906 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 23/60
# 39/39 [==============================] - 16s 418ms/step - loss: 0.7158 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5907 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 24/60
# 39/39 [==============================] - 18s 463ms/step - loss: 0.7125 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5901 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 25/60
# 39/39 [==============================] - 19s 493ms/step - loss: 0.7077 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5901 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 26/60
# 39/39 [==============================] - 21s 552ms/step - loss: 0.7058 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5896 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 27/60
# 39/39 [==============================] - 16s 414ms/step - loss: 0.7014 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5894 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 28/60
# 39/39 [==============================] - 16s 416ms/step - loss: 0.6991 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5892 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 29/60
# 39/39 [==============================] - 17s 448ms/step - loss: 0.6946 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5891 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 30/60
# 39/39 [==============================] - 16s 416ms/step - loss: 0.6920 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5890 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 31/60
# 39/39 [==============================] - 16s 416ms/step - loss: 0.6898 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5887 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 32/60
# 39/39 [==============================] - 16s 420ms/step - loss: 0.6884 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5886 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 33/60
# 39/39 [==============================] - 16s 413ms/step - loss: 0.6834 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5885 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 34/60
# 39/39 [==============================] - 16s 410ms/step - loss: 0.6807 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5884 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 35/60
# 39/39 [==============================] - 17s 421ms/step - loss: 0.6798 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5881 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 36/60
# 39/39 [==============================] - 16s 423ms/step - loss: 0.6764 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5881 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 37/60
# 39/39 [==============================] - 16s 415ms/step - loss: 0.6765 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5879 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 38/60
# 39/39 [==============================] - 17s 432ms/step - loss: 0.6721 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5879 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 39/60
# 39/39 [==============================] - 26s 655ms/step - loss: 0.6710 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5878 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 40/60
# 39/39 [==============================] - 18s 462ms/step - loss: 0.6683 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5876 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 41/60
# 39/39 [==============================] - 19s 486ms/step - loss: 0.6668 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5876 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 42/60
# 39/39 [==============================] - 20s 506ms/step - loss: 0.6657 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5875 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 43/60
# 39/39 [==============================] - 20s 522ms/step - loss: 0.6633 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5874 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 44/60
# 39/39 [==============================] - 19s 498ms/step - loss: 0.6630 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5873 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 45/60
# 39/39 [==============================] - 18s 474ms/step - loss: 0.6608 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5872 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 46/60
# 39/39 [==============================] - 18s 455ms/step - loss: 0.6587 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5872 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 47/60
# 39/39 [==============================] - 17s 448ms/step - loss: 0.6575 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5871 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 48/60
# 39/39 [==============================] - 18s 468ms/step - loss: 0.6565 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5870 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 49/60
# 39/39 [==============================] - 18s 470ms/step - loss: 0.6546 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5869 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 50/60
# 39/39 [==============================] - 18s 459ms/step - loss: 0.6529 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5869 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 51/60
# 39/39 [==============================] - 20s 519ms/step - loss: 0.6525 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5869 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 52/60
# 39/39 [==============================] - 18s 455ms/step - loss: 0.6513 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5868 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 53/60
# 39/39 [==============================] - 18s 458ms/step - loss: 0.6488 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5868 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 54/60
# 39/39 [==============================] - 18s 449ms/step - loss: 0.6489 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5867 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 55/60
# 39/39 [==============================] - 18s 455ms/step - loss: 0.6484 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5866 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 56/60
# 39/39 [==============================] - 18s 455ms/step - loss: 0.6469 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5865 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 57/60
# 39/39 [==============================] - 19s 494ms/step - loss: 0.6455 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5865 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 58/60
# 39/39 [==============================] - 18s 466ms/step - loss: 0.6439 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5865 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 59/60
# 39/39 [==============================] - 18s 456ms/step - loss: 0.6442 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5864 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# Epoch 60/60
# 39/39 [==============================] - 18s 466ms/step - loss: 0.6420 - accuracy: 0.7309 - top-5-accuracy: 1.0000 - val_loss: 0.5865 - val_accuracy: 0.7288 - val_top-5-accuracy: 1.0000
# 11/11 [==============================] - 2s 152ms/step - loss: 0.5851 - accuracy: 0.7301 - top-5-accuracy: 1.0000
# Test accuracy: 73.01%
# Test top 5 accuracy: 100.0%

# %% [markdown]
# ## Inference

# %%
testsamples, labels = next(iter(testloader))
testsamples, labels = testsamples[:NUM_SAMPLES_VIZ], labels[:NUM_SAMPLES_VIZ]

ground_truths = []
preds = []
videos = []

for i, (testsample, label) in enumerate(zip(testsamples, labels)):
    # Generate gif
    with io.BytesIO() as gif:
        imageio.mimsave(gif, (testsample.numpy() * 255).astype("uint8"), "GIF", fps=5)
        videos.append(gif.getvalue())

    # Get model prediction
    output = model.predict(tf.expand_dims(testsample, axis=0))[0]
    pred = np.argmax(output, axis=0)

    ground_truths.append(label.numpy().astype("int"))
    preds.append(pred)


show_samples(ground_truths, preds, videos)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# GridBox(children=(VBox(children=(HTML(value="'T: excitatory synapse | P: excitatory synapse'"), Box(children=(…

# %% [markdown]
# <p align="center">
#   <img width="1000" height="600" src="/ViViT/img/synapse_test_sample.gif">
# </p>
